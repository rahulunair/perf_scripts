# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline

# %%
df = pd.read_csv("./log/perf-out.csv")

# %%
df["EPI"]=df["power/energy-cores/"]/df["instructions"]

# %%
df["Frequency(Mhz)"] = 400

# %%
df.to_csv("./log/EPI_400_load_60.csv")

# %%
df.head()
# Out:
#      task-clock  page-faults       cycles  instructions    branches  \
# 0  41973.520706         3230   9988842067   12912679743  2690189981
# 1  42062.240619         3221  10041126603   12882136838  2674743149
# 2  41750.169434         3220   9986434918   13048050377  2688647018
# 3  41800.682681         3222  10009493963   13067103597  2692427861
# 4  40425.963269         3624   9907864272   13084624110  2694862946
#
#    branch-misses  L1-dcache-loads  L1-dcache-misses  cpu/cache-misses/  \
# 0       12879158       1528696141         185674210           14043563
# 1       12766206       1505094387         180059520           14493353
# 2       12896980       1569063476         185664637           14653043
# 3       12830977       1562923971         186581386           14004315
# 4       12975455       1557700887         189727012           12484011
#
#    LLC-loads  LLC-misses  cpu/cache-references/  power/energy-cores/  \
# 0   20490820      897167              185877664                 6.98
# 1   23182481     1052545              200043906                 6.93
# 2   20833824      834076              191609759                 7.07
# 3   19897141      843883              189834591                 7.05
# 4   20841259      879047              181694455                 7.05
#
#             EPI  Frequency(Mhz)
# 0  5.405539e-10             400
# 1  5.379542e-10             400
# 2  5.418434e-10             400
# 3  5.395228e-10             400
# 4  5.388003e-10             400

# %%
df.tail()
# Out:
#       task-clock  page-faults       cycles  instructions    branches  \
# 27  42827.378878         3616  10684191294   14235316846  2939410534
# 28  40807.026233         3221   9887793148   13005310744  2701235620
# 29  41752.534045         3631  10617811268   14157483957  2974275986
# 30  41934.208257         3216   9976718309   12839740195  2685625961
# 31  42199.951944         3236  10049278290   12926790330  2694603036
#
#     branch-misses  L1-dcache-loads  L1-dcache-misses  cpu/cache-misses/  \
# 27       15330845       1808636687         196137765           15725917
# 28       12286678       1558803523         185339326           12941496
# 29       15883484       1822483223         194724798           15679846
# 30       13150926       1533017350         182976604           15982308
# 31       12962373       1530682380         185300028           14629136
#
#     LLC-loads  LLC-misses  cpu/cache-references/  power/energy-cores/  \
# 27   26888967     1151369              225554536                 7.70
# 28   22291928      868267              177750364                 7.00
# 29   26372765     1118480              257515935                 7.57
# 30   18345089      925383              196271794                 6.97
# 31   21617588     1045031              196568078                 6.97
#
#              EPI  Frequency(Mhz)
# 27  5.409082e-10             400
# 28  5.382417e-10             400
# 29  5.346995e-10             400
# 30  5.428459e-10             400
# 31  5.391903e-10             400
